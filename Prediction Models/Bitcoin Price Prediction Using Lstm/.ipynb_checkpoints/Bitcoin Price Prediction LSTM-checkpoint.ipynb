# %% [markdown]
# # Implementation of LSTM on Bitcoin Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error,r2_score
import warnings
import seaborn as sns
import tensorflow as tf

# %%
warnings.filterwarnings("ignore")

# %%
# Load the data
BTC = pd.read_csv("BTC-USD.csv")

# %%
print(BTC.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# Convert the 'Date' column to datetime and set it as the index
BTC['Date'] = pd.to_datetime(BTC['Date'])
BTC.set_index('Date', inplace=True)

# %%
BTC.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#               Volume
# Date
# 2014-09-17  21056800
# 2014-09-18  34483200
# 2014-09-19  37919700
# 2014-09-20  36863600
# 2014-09-21  26580100

# %%
#Checking null value
print(BTC.isnull().sum())
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Plot the closing prices
plt.figure(figsize=(10, 6))
plt.plot(BTC['Close'], label='BTC Close')
plt.title('BTC Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
# Time Series Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=BTC.index, y=nifty_50_df['Close'])
plt.title('Time Series Scatter Plot of BTC Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.show()

# %%
# Prepare the data for modeling
data = BTC[['Close']].values
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
# Split the data into training and testing sets
train_size = int(len(scaled_data) * 0.7)
train_data, test_data = scaled_data[:train_size], scaled_data[train_size:]

# %%
# Create a function to create datasets for training and testing
def create_dataset(dataset, time_step):
    X, Y = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        X.append(a)
        Y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(Y)

# %%
# Create the training and testing datasets
time_step = 50
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# Reshape the data for GRU layers
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Create the GRU model
model = Sequential()
model.add(LSTM(200, return_sequences=True, input_shape=(time_step, 1)))
model.add(Dropout(0.4))
model.add(LSTM(160, return_sequences=False))
model.add(Dense(50))
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanAbsolutePercentageError()])

# %%
# Train the model
history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - loss: 9.3456e-04 - mean_absolute_percentage_error: 6334.2710 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 7.5628
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 1.0591e-04 - mean_absolute_percentage_error: 1018.6110 - val_loss: 0.0030 - val_mean_absolute_percentage_error: 7.6941
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 1.1633e-04 - mean_absolute_percentage_error: 7816.4395 - val_loss: 0.0024 - val_mean_absolute_percentage_error: 7.0491
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 8.3075e-05 - mean_absolute_percentage_error: 504.8027 - val_loss: 0.0014 - val_mean_absolute_percentage_error: 5.2843
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 6.1255e-05 - mean_absolute_percentage_error: 8174.3931 - val_loss: 0.0013 - val_mean_absolute_percentage_error: 5.4285
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 6.9984e-05 - mean_absolute_percentage_error: 99.3050 - val_loss: 0.0025 - val_mean_absolute_percentage_error: 6.8182
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 5.6695e-05 - mean_absolute_percentage_error: 1054.3582 - val_loss: 0.0010 - val_mean_absolute_percentage_error: 4.5428
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.8794e-05 - mean_absolute_percentage_error: 187.0351 - val_loss: 0.0025 - val_mean_absolute_percentage_error: 6.4947
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 5.5804e-05 - mean_absolute_percentage_error: 1814.9207 - val_loss: 0.0040 - val_mean_absolute_percentage_error: 8.9693
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 6.5772e-05 - mean_absolute_percentage_error: 4588.8706 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 7.1847
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 4.9648e-05 - mean_absolute_percentage_error: 674.5043 - val_loss: 7.7237e-04 - val_mean_absolute_percentage_error: 4.6697
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 4.9525e-05 - mean_absolute_percentage_error: 1800.6107 - val_loss: 0.0041 - val_mean_absolute_percentage_error: 8.4830
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 6.5563e-05 - mean_absolute_percentage_error: 4040.1660 - val_loss: 0.0047 - val_mean_absolute_percentage_error: 10.6343
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 7.2244e-05 - mean_absolute_percentage_error: 758.6786 - val_loss: 0.0031 - val_mean_absolute_percentage_error: 7.8176
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 7.4023e-05 - mean_absolute_percentage_error: 1087.8573 - val_loss: 0.0022 - val_mean_absolute_percentage_error: 5.9852
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.9633e-05 - mean_absolute_percentage_error: 2644.4453 - val_loss: 0.0035 - val_mean_absolute_percentage_error: 8.2766
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.6292e-05 - mean_absolute_percentage_error: 297.4688 - val_loss: 0.0022 - val_mean_absolute_percentage_error: 5.7070
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.2596e-05 - mean_absolute_percentage_error: 764.3101 - val_loss: 9.8909e-04 - val_mean_absolute_percentage_error: 4.9153
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.9494e-05 - mean_absolute_percentage_error: 7113.5874 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 4.6490
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 5.1483e-05 - mean_absolute_percentage_error: 248.3509 - val_loss: 0.0016 - val_mean_absolute_percentage_error: 4.8916
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 5.4170e-05 - mean_absolute_percentage_error: 2772.0061 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 11.0825
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 8.3230e-05 - mean_absolute_percentage_error: 1567.4910 - val_loss: 0.0044 - val_mean_absolute_percentage_error: 8.1850
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 5.4889e-05 - mean_absolute_percentage_error: 5557.3311 - val_loss: 7.5806e-04 - val_mean_absolute_percentage_error: 4.9037
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 5.3994e-05 - mean_absolute_percentage_error: 988.3615 - val_loss: 7.0361e-04 - val_mean_absolute_percentage_error: 4.0240
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.7349e-05 - mean_absolute_percentage_error: 292.9031 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 4.1635
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 6.6912e-05 - mean_absolute_percentage_error: 614.2693 - val_loss: 0.0016 - val_mean_absolute_percentage_error: 4.9561
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 5.3310e-05 - mean_absolute_percentage_error: 382.2147 - val_loss: 6.1011e-04 - val_mean_absolute_percentage_error: 4.9062
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.4019e-05 - mean_absolute_percentage_error: 1867.5616 - val_loss: 0.0015 - val_mean_absolute_percentage_error: 4.7577
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.7360e-05 - mean_absolute_percentage_error: 2654.7888 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 4.4042
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 5.0328e-05 - mean_absolute_percentage_error: 10450.4170 - val_loss: 0.0032 - val_mean_absolute_percentage_error: 6.9876
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.0789e-05 - mean_absolute_percentage_error: 1524.9989 - val_loss: 0.0026 - val_mean_absolute_percentage_error: 6.0299
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.6128e-05 - mean_absolute_percentage_error: 95.4812 - val_loss: 0.0044 - val_mean_absolute_percentage_error: 8.5315
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.5721e-05 - mean_absolute_percentage_error: 2680.2915 - val_loss: 0.0019 - val_mean_absolute_percentage_error: 5.2643
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.8169e-05 - mean_absolute_percentage_error: 1601.8258 - val_loss: 0.0024 - val_mean_absolute_percentage_error: 6.3191
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.1726e-05 - mean_absolute_percentage_error: 357.6598 - val_loss: 0.0039 - val_mean_absolute_percentage_error: 8.9009
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 4.9945e-05 - mean_absolute_percentage_error: 1982.7183 - val_loss: 0.0031 - val_mean_absolute_percentage_error: 7.0954
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 4.3548e-05 - mean_absolute_percentage_error: 3072.9231 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 6.7503
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 4.1372e-05 - mean_absolute_percentage_error: 369.3521 - val_loss: 0.0016 - val_mean_absolute_percentage_error: 4.8071
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 3.9119e-05 - mean_absolute_percentage_error: 2531.5281 - val_loss: 8.4789e-04 - val_mean_absolute_percentage_error: 4.1872
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 4.1736e-05 - mean_absolute_percentage_error: 186.6775 - val_loss: 0.0013 - val_mean_absolute_percentage_error: 4.3535
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.0967e-05 - mean_absolute_percentage_error: 3119.4128 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 4.1578
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.3203e-05 - mean_absolute_percentage_error: 286.2504 - val_loss: 0.0013 - val_mean_absolute_percentage_error: 4.9916
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 4.9291e-05 - mean_absolute_percentage_error: 880.4064 - val_loss: 0.0017 - val_mean_absolute_percentage_error: 4.7630
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 3.2202e-05 - mean_absolute_percentage_error: 149.4473 - val_loss: 0.0042 - val_mean_absolute_percentage_error: 8.9403
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.3330e-05 - mean_absolute_percentage_error: 1935.5453 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 6.2180
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.0304e-05 - mean_absolute_percentage_error: 1176.3553 - val_loss: 0.0036 - val_mean_absolute_percentage_error: 7.7830
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.1335e-05 - mean_absolute_percentage_error: 967.2071 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 4.3959
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.0895e-05 - mean_absolute_percentage_error: 887.9686 - val_loss: 0.0037 - val_mean_absolute_percentage_error: 7.0067
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.0970e-05 - mean_absolute_percentage_error: 256.8599 - val_loss: 0.0017 - val_mean_absolute_percentage_error: 4.8695
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 4.2376e-05 - mean_absolute_percentage_error: 977.0376 - val_loss: 0.0040 - val_mean_absolute_percentage_error: 8.2062

# %%
# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
# Inverse transform the predictions
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
# Inverse transform the original values
original_y_train = scaler.inverse_transform([y_train])
original_y_test = scaler.inverse_transform([y_test])

# %%
# Create plots for the predicted values
train_predict_plot = np.empty_like(scaled_data)
train_predict_plot[:, :] = np.nan
train_predict_plot[time_step:len(train_predict) + time_step, :] = train_predict

# %%
test_predict_plot = np.empty_like(scaled_data)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + (time_step * 2) + 1:len(scaled_data) - 1, :] = test_predict

# %%
plt.figure(figsize=(10, 6))
plt.plot(scaler.inverse_transform(scaled_data), label='Actual')
plt.plot(train_predict_plot, label='Train Predict')
plt.plot(test_predict_plot, label='Test Predict')
plt.title('Actual vs Predicted Values')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
# Plot the model loss and MAPE over epochs
plt.figure(figsize=(12, 6))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss (MSE) Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()

# Plot MAPE
plt.subplot(1, 2, 2)
plt.plot(history.history['mean_absolute_percentage_error'], label='Training MAPE')
plt.plot(history.history['val_mean_absolute_percentage_error'], label='Validation MAPE')
plt.title('Model Accuracy (MAPE) Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MAPE (%)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Plot true vs predicted residuals
plt.figure(figsize=(12, 6))
plt.plot(scaler.inverse_transform(scaled_data), label="True")
plt.plot(test_predict_plot, label="Test Predicted")
plt.title("True vs Predicted BTC   Close Prices")
plt.legend()
plt.show()

# %%
# Calculate R² score, rmse, mae, mse, mate, smate for training and testing sets
train_r2 = r2_score(original_y_train[0], train_predict[:, 0])
test_r2 = r2_score(original_y_test[0], test_predict[:, 0])

train_rmse = np.sqrt(mean_squared_error(original_y_train[0], train_predict[:, 0]))
test_rmse = np.sqrt(mean_squared_error(original_y_test[0], test_predict[:, 0]))

train_mae = mean_absolute_error(original_y_train[0], train_predict[:, 0])
test_mae = mean_absolute_error(original_y_test[0], test_predict[:, 0])

train_mse = mean_squared_error(original_y_train[0], train_predict[:, 0])
test_mse = mean_squared_error(original_y_test[0], test_predict[:, 0])

train_mate = median_absolute_error(original_y_train[0], train_predict[:, 0])
test_mate = median_absolute_error(original_y_test[0], test_predict[:, 0])

train_smate = np.sqrt(mean_squared_error(original_y_train[0], train_predict[:, 0])) / np.mean(original_y_train)
test_smate = np.sqrt(mean_squared_error(original_y_test[0], test_predict[:, 0])) / np.mean(original_y_test)

print(f'Train R²: {train_r2}')
print(f'Test R²: {test_r2}')

print("Training RMSE: ", train_rmse)
print("Testing RMSE: ", test_rmse)

print("Training MAE: ", train_mae)
print("Testing MAE: ", test_mae)

print("Training MSE: ", train_mse)
print("Testing MSE: ", test_mse)

print("Training MATE: ", train_mate)
print("Testing MATE: ", test_mate)

print("Training SMATE: ", train_smate)
print("Testing SMATE: ", test_smate)
# Out:
# Train R²: 0.9908917580432313
# Test R²: 0.9505946512099303
# Training RMSE:  379.70474936296483
# Testing RMSE:  4269.376224219396
# Training MAE:  209.93181744027748
# Testing MAE:  3096.8610011811516
# Training MSE:  144175.69668879194
# Testing MSE:  18227573.34392987
# Training MATE:  80.32775864843757
# Testing MATE:  2231.859374874999
# Training SMATE:  0.10018216309141781
# Testing SMATE:  0.13996355131035762

# %%
from tabulate import tabulate
import numpy as np
# Create a table
table = [
    ["Metric", "Training", "Testing"],
    ["R² Score", f"{train_r2:.4f}", f"{test_r2:.4f}"],
    ["RMSE", f"{train_rmse:.4f}", f"{test_rmse:.4f}"],
    ["MSE", f"{train_mse:.4f}", f"{test_mse:.4f}"],
    ["MAE", f"{train_mae:.4f}", f"{test_mae:.4f}"],
    ["MATE", f"{train_mate:.4f}", f"{test_mate:.4f}"],
    ["SMATE", f"{train_smate:.4f}", f"{test_smate:.4f}"]
]

print(tabulate(table, headers="firstrow", tablefmt="grid"))
# Out:
# +----------+-------------+----------------+
# | Metric   |    Training |        Testing |
# +==========+=============+================+
# | R² Score |      0.9909 |    0.9506      |
# +----------+-------------+----------------+
# | RMSE     |    379.705  | 4269.38        |
# +----------+-------------+----------------+
# | MSE      | 144176      |    1.82276e+07 |
# +----------+-------------+----------------+
# | MAE      |    209.932  | 3096.86        |
# +----------+-------------+----------------+
# | MATE     |     80.3278 | 2231.86        |
# +----------+-------------+----------------+
# | SMATE    |      0.1002 |    0.14        |
# +----------+-------------+----------------+
