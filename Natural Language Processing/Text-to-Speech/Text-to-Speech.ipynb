# %%
# !git clone https://github.com/PrasannaKasar/Text-to-Speech

# %%
# !python3 /kaggle/working/Text-to-Speech/hyperparams.py

# %%
# !pip install unidecode tqdm inflect

# %%
# !python3 /kaggle/working/Text-to-Speech/prepare_data.py

# %%
# !python3 /kaggle/working/Text-to-Speech/train_transformer.py

# %%
# !python3 /kaggle/working/Text-to-Speech/train_postnet.py

# %%
# !python3 /kaggle/input/text-to-speech-temp-clone/Text-to-Speech-main/synthesis.py --transformer_checkpoint /kaggle/input/trained-model-checkpoints/checkpoint_transformer_50000.pth.tar \
                   --postnet_checkpoint /kaggle/input/trained-model-checkpoints/checkpoint_postnet_45000.pth.tar \
                   --max_len 400 \
                   --text "Hello World!!"
